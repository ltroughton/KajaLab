# %%
import sys
sys.path.append("/Users/leetroughton/Documents/GitHub/Troughton/KajaLab")

from seahorse_prepare import prepare
prepare("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/Lee/New/XJB_Edaravone/N1/XJB_Edaravone_data.xlsx")

# %%
import importlib
import seahorse_analyze
importlib.reload(seahorse_analyze)
from seahorse_analyze import analyze

analyze("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/Lee/New/XJB_Edaravone/N1/XJB_Edaravone_data_prepared.xlsx", baseline=(1,40), oligomycin=(41,43), fccp=(44,46), rotaa=(47,49))
