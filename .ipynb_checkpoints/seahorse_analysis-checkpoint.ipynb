# %%
import sys
sys.path.append("/Users/leetroughton/Documents/GitHub/Troughton/KajaLab")

from seahorse_prepare import prepare
prepare("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/XJB_Edaravone/N3/XJB_Edaravone_data.xlsx")

# %%
import importlib
import seahorse_analyze
importlib.reload(seahorse_analyze)
from seahorse_analyze import analyze

analyze("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/XJB_Edaravone/N3/XJB_Edaravone_data_prepared.xlsx", baseline=(1,40), oligomycin=(41,43), fccp=(44,46), rotaa=(47,49))

# %%
from seahorse_collate import collate, collate_timeseries

collate("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours")           # normalised (default)
collate("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours", mode="raw")  # raw

collate_timeseries("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours")            # normalised
collate_timeseries("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/NM 48 Hours", mode="raw") # raw
# Out:
#   Loaded: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours/N1/analysis/normalised/parameters.csv
#   Loaded: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours/N2/analysis/normalised/parameters.csv
#   Loaded: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours/N3/analysis/normalised/parameters.csv
#
# ✓ Collation complete. CSVs written to: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours/collated/normalised/
#   Loaded: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 48 Hours/N1/analysis/raw/parameters.csv
# ...
