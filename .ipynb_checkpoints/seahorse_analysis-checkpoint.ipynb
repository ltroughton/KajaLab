# %%
import sys
sys.path.append("/Users/leetroughton/Documents/GitHub/Troughton/KajaLab")

from seahorse_prepare import prepare
prepare("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 24 Hours/N1/PM_24_data.xlsx")
# Out:
# Input : /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 24 Hours/N1/PM_24_data.xlsx
# Output: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 24 Hours/N1/PM_24_data_prepared.xlsx
#
# Parsing Hoechst...
#   Background mean fluorescence: 14455.9
#   Reference well: B1, BG-subtracted fluorescence: 106932.1
# Parsing OCR...
# Parsing ECAR...
# Normalising...
#   ⚠  132 data columns vs 72 wells — normalising up to min(132, 72)
#   ⚠  132 data columns vs 72 wells — normalising up to min(132, 72)
#
# Writing sheets...
#   ✓ Hoescht (original)
#   ✓ Hoescht_factors
#   ✓ OCR_raw
#   ✓ OCR_adjusted
#   ✓ OCR_raw_cleaned
#   ✓ OCR_cleaned
#   ✓ ECAR_raw
#   ✓ ECAR_adjusted
#   ✓ ECAR_raw_cleaned
#   ✓ ECAR_cleaned
#
# ✓ Saved: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/PM 24 Hours/N1/PM_24_data_prepared.xlsx
# ...

# %%
import importlib
import seahorse_analyze
importlib.reload(seahorse_analyze)
from seahorse_analyze import analyze

analyze("/Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/NWD-19_SKQ1/N1/NWD19_SKQ1_data_prepared.xlsx", baseline=(1,40), oligomycin=(41,43), fccp=(44,46), rotaa=(47,49))
# Out:
# Reading: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/NWD-19_SKQ1/N1/NWD19_SKQ1_data_prepared.xlsx
#
# ── Normalised (Hoechst-corrected) ──
# Treatments: ['Media only', 'DMSO', '10uM NWD-19', '5uM NWD-19', '1uM NWD-19', '0.5uM NWD-19', '0.1uM NWD-19', '1uM SKQ1', '0.5uM SKQ1', '0.1uM SKQ1', '0.05uM SKQ1', '0.01uM SKQ1']
#   Saved: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/NWD-19_SKQ1/N1/analysis/normalised/parameters.csv
#   Saved: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/NWD-19_SKQ1/N1/analysis/normalised/summary.csv
#   Plots: /Users/leetroughton/Library/CloudStorage/OneDrive-LoyolaUniversityChicago/Research - Lee/Data/Seahorse/New/NWD-19_SKQ1/N1/analysis/normalised/seahorse_metric_plots/
# ...
